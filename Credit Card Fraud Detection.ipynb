# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data_train = pd.read_csv('/content/fraudTrain.csv')

# %%
data_train.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2019-01-01 00:00:18  2703186189652095
# 1           1   2019-01-01 00:00:44      630423337322
# 2           2   2019-01-01 00:00:51    38859492057661
# 3           3   2019-01-01 00:01:16  3534093764340240
# 4           4   2019-01-01 00:03:06   375534208663984
#
#                              merchant       category     amt      first  \
# 0          fraud_Rippin, Kub and Mann       misc_net    4.97   Jennifer
# 1     fraud_Heller, Gutmann and Zieme    grocery_pos  107.23  Stephanie
# 2                fraud_Lind-Buckridge  entertainment  220.11     Edward
# 3  fraud_Kutch, Hermiston and Farrell  gas_transport   45.00     Jeremy
# 4                 fraud_Keeling-Crist       misc_pos   41.96      Tyler
#
#       last gender                        street  ...      lat      long  \
# 0    Banks      F                561 Perry Cove  ...  36.0788  -81.1781
# ...

# %%
data_train.tail()
# Out:
#         Unnamed: 0 trans_date_trans_time           cc_num  \
# 321863      321863   2019-06-03 04:36:36   38052002992326
# 321864      321864   2019-06-03 04:36:41   38199021865320
# 321865      321865   2019-06-03 04:37:25     501802953619
# 321866      321866   2019-06-03 04:38:12    4247921790666
# 321867      321867   2019-06-03 04:38:25  180065479077096
#
#                                  merchant       category    amt   first  \
# 321863                  fraud_Hintz-Bruen    grocery_net  29.05    Anna
# 321864                fraud_Friesen-Stamm  gas_transport  71.52   Jesse
# 321865                 fraud_Donnelly PLC       misc_net   6.48  Robert
# 321866                  fraud_Reichel Inc  entertainment  27.75  Judith
# 321867  fraud_Goyette, Howell and Collier           shop    NaN     NaN
#
#            last gender                           street  ...      lat  \
# 321863    Logan      F        3522 Park Wells Suite 528  ...  30.3300
# ...

# %%
data_train.shape
# Out:
# (321868, 23)

# %%
data_train.columns
# Out:
# Index(['Unnamed: 0', 'trans_date_trans_time', 'cc_num', 'merchant', 'category',
#        'amt', 'first', 'last', 'gender', 'street', 'city', 'state', 'zip',
#        'lat', 'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time',
#        'merch_lat', 'merch_long', 'is_fraud'],
#       dtype='object')

# %%
data_train.duplicated().sum()
# Out:
# np.int64(0)

# %%
data_train.isnull().sum()
# Out:
# Unnamed: 0               0
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      1
# first                    1
# last                     1
# gender                   1
# street                   1
# city                     1
# state                    1
# zip                      1
# lat                      1
# long                     1
# city_pop                 1
# job                      1
# dob                      1
# trans_num                1
# unix_time                1
# merch_lat                1
# merch_long               1
# is_fraud                 1
# dtype: int64

# %%
data_train.dropna(inplace = True)

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 321867 entries, 0 to 321866
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             321867 non-null  int64
#  1   trans_date_trans_time  321867 non-null  object
#  2   cc_num                 321867 non-null  int64
#  3   merchant               321867 non-null  object
#  4   category               321867 non-null  object
#  5   amt                    321867 non-null  float64
#  6   first                  321867 non-null  object
#  7   last                   321867 non-null  object
#  8   gender                 321867 non-null  object
#  9   street                 321867 non-null  object
#  10  city                   321867 non-null  object
#  11  state                  321867 non-null  object
#  12  zip                    321867 non-null  float64
#  13  lat                    321867 non-null  float64
# ...

# %%
data_train.describe()
# Out:
#           Unnamed: 0        cc_num            amt            zip  \
# count  321867.000000  3.218670e+05  321867.000000  321867.000000
# mean   160933.000000  4.161989e+17      70.695886   48767.703244
# std     92915.143884  1.307246e+18     157.374640   26908.090830
# min         0.000000  6.041621e+10       1.000000    1257.000000
# 25%     80466.500000  1.800365e+14       9.650000   26041.000000
# 50%    160933.000000  3.519607e+15      47.610000   48174.000000
# 75%    241399.500000  4.642255e+15      83.340000   72011.000000
# max    321866.000000  4.992346e+18   17897.240000   99783.000000
#
#                  lat           long      city_pop     unix_time  \
# count  321867.000000  321867.000000  3.218670e+05  3.218670e+05
# mean       38.537481     -90.212119  8.958621e+04  1.332580e+09
# std         5.077906      13.772658  3.036944e+05  3.810850e+06
# min        20.027100    -165.672300  2.300000e+01  1.325376e+09
# ...

# %%
data_train.describe(include = 'object')
# Out:
#        trans_date_trans_time           merchant       category        first  \
# count                 321867             321867         321867       321867
# unique                317221                693             14          341
# top      2019-04-22 16:02:01  fraud_Kilback LLC  gas_transport  Christopher
# freq                       4               1086          32667         6786
#
#           last  gender                    street        city   state  \
# count   321867  321867                    321867      321867  321867
# unique     472       2                       936         859      51
# top      Smith       F  11014 Chad Lake Apt. 573  Birmingham      TX
# freq      7179  175985                       817        1389   23481
#
#                       job         dob                         trans_num
# count              321867      321867                            321867
# unique                481         922                            321867
# ...

# %%
data_train.nunique()
# Out:
# Unnamed: 0               321867
# trans_date_trans_time    317221
# cc_num                      936
# merchant                    693
# category                     14
# amt                       31551
# first                       341
# last                        472
# gender                        2
# street                      936
# city                        859
# state                        51
# zip                         925
# lat                         923
# long                        924
# city_pop                    845
# job                         481
# dob                         922
# trans_num                321867
# unix_time                317253
# merch_lat                318744
# merch_long               320542
# is_fraud                      2
# dtype: int64

# %%
data_train.drop(columns=['Unnamed: 0','cc_num','first', 'last', 'street', 'city', 'state', 'zip', 'dob', 'trans_date_trans_time'],inplace=True)

# %%
data_train
# Out:
#                                   merchant       category     amt gender  \
# 0               fraud_Rippin, Kub and Mann       misc_net    4.97      F
# 1          fraud_Heller, Gutmann and Zieme    grocery_pos  107.23      F
# 2                     fraud_Lind-Buckridge  entertainment  220.11      M
# 3       fraud_Kutch, Hermiston and Farrell  gas_transport   45.00      M
# 4                      fraud_Keeling-Crist       misc_pos   41.96      M
# ...                                    ...            ...     ...    ...
# 321862              fraud_Pacocha-O'Reilly    grocery_pos  119.85      M
# 321863                   fraud_Hintz-Bruen    grocery_net   29.05      F
# 321864                 fraud_Friesen-Stamm  gas_transport   71.52      M
# 321865                  fraud_Donnelly PLC       misc_net    6.48      M
# 321866                   fraud_Reichel Inc  entertainment   27.75      F
#
#             lat      long  city_pop  \
# 0       36.0788  -81.1781    3495.0
# ...

# %%
data_train.nunique()
# Out:
# merchant         693
# category          14
# amt            31551
# gender             2
# lat              923
# long             924
# city_pop         845
# job              481
# trans_num     321867
# unix_time     317253
# merch_lat     318744
# merch_long    320542
# is_fraud           2
# dtype: int64

# %%
object_columns = data_train.select_dtypes(include=['object']).columns
print("Object type columns:")
print(object_columns)

numerical_columns = data_train.select_dtypes(include=['int64', 'float64']).columns
print("\nNumerical type columns:")
print(numerical_columns)
# Out:
# Object type columns:
# Index(['merchant', 'category', 'gender', 'job', 'trans_num'], dtype='object')
#
# Numerical type columns:
# Index(['amt', 'lat', 'long', 'city_pop', 'unix_time', 'merch_lat',
#        'merch_long', 'is_fraud'],
#       dtype='object')

# %%
def classify_features(data_train):
    categorical_features = []
    non_categorical_features = []
    discrete_features = []
    continuous_features = []

    for column in data_train.columns:
        if data_train[column].dtype == 'object':
            if data_train[column].nunique() < 10:
                categorical_features.append(column)
            else:
                non_categorical_features.append(column)
        elif data_train[column].dtype in ['int64']:
            if data_train[column].nunique() < 15:
                discrete_features.append(column)
            else:
                continuous_features.append(column)

    return categorical_features, non_categorical_features, discrete_features, continuous_features

# %%
categorical, non_categorical, discrete, continuous = classify_features(data_train)

# %%
print("Categorical Features:", categorical)
print("Non-Categorical Features:", non_categorical)
print("Discrete Features:", discrete)
print("Continuous Features:", continuous)
# Out:
# Categorical Features: ['gender']
# Non-Categorical Features: ['merchant', 'category', 'job', 'trans_num']
# Discrete Features: []
# Continuous Features: []

# %%
for i in discrete:
  print(i)
  print(data_train[i].unique())

# %%
for i in discrete:
  print(i)
  print(data_train[i].value_counts())

# %%
from sklearn.preprocessing import LabelEncoder

# %%
data_train = pd.get_dummies(data_train,columns =['category','gender'])

# %%
data_train
# Out:
#                                   merchant     amt      lat      long  \
# 0               fraud_Rippin, Kub and Mann    4.97  36.0788  -81.1781
# 1          fraud_Heller, Gutmann and Zieme  107.23  48.8878 -118.2105
# 2                     fraud_Lind-Buckridge  220.11  42.1808 -112.2620
# 3       fraud_Kutch, Hermiston and Farrell   45.00  46.2306 -112.1138
# 4                      fraud_Keeling-Crist   41.96  38.4207  -79.4629
# ...                                    ...     ...      ...       ...
# 321862              fraud_Pacocha-O'Reilly  119.85  38.0460 -122.1866
# 321863                   fraud_Hintz-Bruen   29.05  30.3300  -95.0202
# 321864                 fraud_Friesen-Stamm   71.52  43.1960  -72.3001
# 321865                  fraud_Donnelly PLC    6.48  41.5403 -122.9366
# 321866                   fraud_Reichel Inc   27.75  39.5370  -83.4550
#
#         city_pop                                          job  \
# 0         3495.0                    Psychologist, counselling
# ...

# %%
encoder = LabelEncoder()
data_train["merchant"] = encoder.fit_transform(data_train["merchant"])
data_train["trans_num"] = encoder.fit_transform(data_train["trans_num"])
data_train["job"] = encoder.fit_transform(data_train["job"])

# %%
for i in discrete:
    plt.figure(figsize=(15, 6))
    ax = sns.countplot(x=i, data=data_train, palette='hls')

    for p in ax.patches:
        height = p.get_height()
        ax.annotate(f'{height}',
                    xy=(p.get_x() + p.get_width() / 2., height),
                    xytext=(0, 10),
                    textcoords='offset points',
                    ha='center', va='center')

    plt.show()

# %%
for i in discrete:
    plt.figure(figsize=(6,6))
    counts = data_train[i].value_counts()
    plt.pie(counts, labels=counts.index, autopct='%1.1f%%', colors=['skyblue', 'lightgreen'])
    plt.title(f'Distribution of {i}')
    plt.axis('equal')
    plt.show()

# %%
for i in continuous:
    plt.figure(figsize=(15,6))
    sns.histplot(data_train[i], bins = 20, kde = True, palette='hls')
    plt.xticks(rotation = 90)
    plt.show()

# %%
for i in continuous:
    plt.figure(figsize=(15, 6))
    sns.boxplot(x=i, data=data_train, palette='hls')
    plt.xticks(rotation=90)
    plt.show()

# %%
for i in continuous:
    plt.figure(figsize=(15, 6))
    sns.boxenplot(x=i, data=data_train, palette='hls')
    plt.xticks(rotation=90)
    plt.show()

# %%
for i in continuous:
    plt.figure(figsize=(15, 6))
    sns.violinplot(x=i, data=data_train, palette='hls')
    plt.xticks(rotation=90)
    plt.show()

# %%
plt.figure(figsize=(8, 6))

counts = data_train['gender_F'].value_counts()
plt.pie(counts, labels=counts.index, autopct='%1.1f%%', colors=['skyblue', 'lightgreen'])

plt.title(f'Distribution of gender')
plt.axis('equal')
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
X = data_train.drop(columns=["is_fraud"], inplace = False)
y = data_train["is_fraud"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify = y, random_state=42)

# %%
from imblearn.over_sampling import SMOTE

# %%
smote = SMOTE()
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# %%
log_reg_model = LogisticRegression()
log_reg_model.fit(X_train_resampled, y_train_resampled)
# Out:
# LogisticRegression()

# %%
log_reg_pred = log_reg_model.predict(X_test)
log_reg_accuracy = accuracy_score(y_test, log_reg_pred)
print("Logistic Regression Accuracy:", log_reg_accuracy)
# Out:
# Logistic Regression Accuracy: 0.9469195637990493

# %%
y_pred_train = log_reg_model.predict(X_train)
train_accuracy = accuracy_score(y_train, y_pred_train)
print("Training Accuracy:", train_accuracy)
# Out:
# Training Accuracy: 0.947882078347761

# %%
dt_model = DecisionTreeClassifier()
dt_model.fit(X_train_resampled, y_train_resampled)
# Out:
# DecisionTreeClassifier()

# %%
dt_pred = dt_model.predict(X_test)
dt_accuracy = accuracy_score(y_test, dt_pred)
print("Decision Tree Accuracy:", dt_accuracy)
# Out:
# Decision Tree Accuracy: 0.9919066703948799

# %%
y_pred_train = dt_model.predict(X_train)
train_accuracy = accuracy_score(y_train, y_pred_train)
print("Training Accuracy:", train_accuracy)
# Out:
# Training Accuracy: 1.0
